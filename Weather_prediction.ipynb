# %%
# IMPORT LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

sns.set(style="whitegrid")

# %%
# LOADING THE DATASETS

# Load all weather data files
temperature_df = pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\WEATHER PREDICTION PROJECT\temperature.csv')
humidity_df = pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\WEATHER PREDICTION PROJECT\humidity.csv')
pressure_df = pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\WEATHER PREDICTION PROJECT\pressure.csv')
wind_speed_df = pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\WEATHER PREDICTION PROJECT\wind_speed.csv')
wind_direction_df = pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\WEATHER PREDICTION PROJECT\wind_direction.csv')
weather_description_df = pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\WEATHER PREDICTION PROJECT\weather_description.csv')

# Display the first few rows of each DataFrame to understand their structure
print("Temperature Data:")
print(temperature_df.head())
print("\nHumidity Data:")
print(humidity_df.head())
print("\nPressure Data:")
print(pressure_df.head())
print("\nWind Speed Data:")
print(wind_speed_df.head())
print("\nWind Direction Data:")
print(wind_direction_df.head())
print("\nWeather Description Data:")
print(weather_description_df.head())
# Out:
# Temperature Data:
#               datetime   Vancouver    Portland  San Francisco     Seattle  \
# 0  2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 1  2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2  2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 3  2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 4  2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
#
#    Los Angeles   San Diego   Las Vegas     Phoenix  Albuquerque  ...  \
# 0          NaN         NaN         NaN         NaN          NaN  ...
# 1   291.870000  291.530000  293.410000  296.600000   285.120000  ...
# 2   291.868186  291.533501  293.403141  296.608509   285.154558  ...
# 3   291.862844  291.543355  293.392177  296.631487   285.233952  ...
# 4   291.857503  291.553209  293.381213  296.654466   285.313345  ...
#
#    Philadelphia    New York    Montreal      Boston   Beersheba  \
# 0           NaN         NaN         NaN         NaN         NaN
# 1    285.630000  288.220000  285.830000  287.170000  307.590000
# 2    285.663208  288.247676  285.834650  287.186092  307.590000
# 3    285.756824  288.326940  285.847790  287.231672  307.391513
# 4    285.850440  288.406203  285.860929  287.277251  307.145200
#
#    Tel Aviv District       Eilat  Haifa  Nahariyya  Jerusalem
# 0                NaN  309.100000    NaN        NaN        NaN
# 1         305.470000  310.580000  304.4      304.4      303.5
# 2         304.310000  310.495769  304.4      304.4      303.5
# 3         304.281841  310.411538  304.4      304.4      303.5
# 4         304.238015  310.327308  304.4      304.4      303.5
#
# [5 rows x 37 columns]
#
# Humidity Data:
#               datetime  Vancouver  Portland  San Francisco  Seattle  \
# 0  2012-10-01 12:00:00        NaN       NaN            NaN      NaN
# 1  2012-10-01 13:00:00       76.0      81.0           88.0     81.0
# 2  2012-10-01 14:00:00       76.0      80.0           87.0     80.0
# 3  2012-10-01 15:00:00       76.0      80.0           86.0     80.0
# 4  2012-10-01 16:00:00       77.0      80.0           85.0     79.0
#
#    Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  Philadelphia  \
# 0          NaN        NaN        NaN      NaN          NaN  ...           NaN
# 1         88.0       82.0       22.0     23.0         50.0  ...          71.0
# 2         88.0       81.0       21.0     23.0         49.0  ...          70.0
# 3         88.0       81.0       21.0     23.0         49.0  ...          70.0
# 4         88.0       81.0       21.0     23.0         49.0  ...          69.0
#
#    New York  Montreal  Boston  Beersheba  Tel Aviv District  Eilat  Haifa  \
# 0       NaN       NaN     NaN        NaN                NaN   25.0    NaN
# 1      58.0      93.0    68.0       50.0               63.0   22.0   51.0
# 2      57.0      91.0    68.0       51.0               62.0   22.0   51.0
# 3      57.0      87.0    68.0       51.0               62.0   22.0   51.0
# 4      57.0      84.0    68.0       52.0               62.0   22.0   51.0
#
#    Nahariyya  Jerusalem
# 0        NaN        NaN
# 1       51.0       50.0
# 2       51.0       50.0
# 3       51.0       50.0
# 4       51.0       50.0
#
# [5 rows x 37 columns]
#
# Pressure Data:
#               datetime  Vancouver  Portland  San Francisco  Seattle  \
# 0  2012-10-01 12:00:00        NaN       NaN            NaN      NaN
# 1  2012-10-01 13:00:00        NaN    1024.0         1009.0   1027.0
# 2  2012-10-01 14:00:00        NaN    1024.0         1009.0   1027.0
# 3  2012-10-01 15:00:00        NaN    1024.0         1009.0   1028.0
# 4  2012-10-01 16:00:00        NaN    1024.0         1009.0   1028.0
#
#    Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  Philadelphia  \
# 0          NaN        NaN        NaN      NaN          NaN  ...           NaN
# 1       1013.0     1013.0     1018.0   1013.0       1024.0  ...        1014.0
# 2       1013.0     1013.0     1018.0   1013.0       1024.0  ...        1014.0
# 3       1013.0     1013.0     1018.0   1013.0       1024.0  ...        1014.0
# 4       1013.0     1013.0     1018.0   1013.0       1024.0  ...        1014.0
#
#    New York  Montreal  Boston  Beersheba  Tel Aviv District   Eilat   Haifa  \
# 0       NaN       NaN     NaN        NaN                NaN  1011.0     NaN
# 1    1012.0    1001.0  1014.0      984.0             1012.0  1010.0  1013.0
# 2    1012.0     986.0  1014.0      984.0             1012.0  1010.0  1013.0
# 3    1012.0     945.0  1014.0      984.0             1012.0  1010.0  1013.0
# 4    1012.0     904.0  1014.0      984.0             1012.0  1010.0  1013.0
#
#    Nahariyya  Jerusalem
# 0        NaN        NaN
# 1     1013.0      990.0
# 2     1013.0      990.0
# 3     1013.0      990.0
# 4     1013.0      990.0
#
# [5 rows x 37 columns]
#
# Wind Speed Data:
#               datetime  Vancouver  Portland  San Francisco  Seattle  \
# 0  2012-10-01 12:00:00        NaN       NaN            NaN      NaN
# 1  2012-10-01 13:00:00        0.0       0.0            2.0      0.0
# 2  2012-10-01 14:00:00        0.0       0.0            2.0      0.0
# 3  2012-10-01 15:00:00        0.0       0.0            2.0      0.0
# 4  2012-10-01 16:00:00        0.0       0.0            2.0      0.0
#
#    Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  Philadelphia  \
# 0          NaN        NaN        NaN      NaN          NaN  ...           NaN
# 1          0.0        0.0        0.0      2.0          4.0  ...           4.0
# 2          0.0        0.0        0.0      2.0          4.0  ...           4.0
# 3          0.0        0.0        0.0      2.0          4.0  ...           3.0
# 4          0.0        0.0        0.0      2.0          4.0  ...           3.0
#
#    New York  Montreal  Boston  Beersheba  Tel Aviv District  Eilat  Haifa  \
# 0       NaN       NaN     NaN        NaN                NaN    8.0    NaN
# 1       7.0       4.0     3.0        1.0                0.0    8.0    2.0
# 2       7.0       4.0     3.0        3.0                0.0    8.0    2.0
# 3       7.0       4.0     3.0        3.0                0.0    8.0    2.0
# 4       7.0       4.0     3.0        3.0                0.0    8.0    2.0
#
#    Nahariyya  Jerusalem
# 0        NaN        NaN
# 1        2.0        2.0
# 2        2.0        2.0
# 3        2.0        2.0
# 4        2.0        2.0
#
# [5 rows x 37 columns]
#
# Wind Direction Data:
#               datetime  Vancouver  Portland  San Francisco  Seattle  \
# 0  2012-10-01 12:00:00        NaN       NaN            NaN      NaN
# 1  2012-10-01 13:00:00        0.0       0.0          150.0      0.0
# 2  2012-10-01 14:00:00        6.0       4.0          147.0      2.0
# 3  2012-10-01 15:00:00       20.0      18.0          141.0     10.0
# 4  2012-10-01 16:00:00       34.0      31.0          135.0     17.0
#
#    Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  Philadelphia  \
# 0          NaN        NaN        NaN      NaN          NaN  ...           NaN
# 1          0.0        0.0        0.0     10.0        360.0  ...         270.0
# 2          0.0        0.0        8.0      9.0        360.0  ...         270.0
# 3          0.0        0.0       23.0      9.0        360.0  ...         271.0
# 4          0.0        0.0       37.0      9.0        360.0  ...         272.0
#
#    New York  Montreal  Boston  Beersheba  Tel Aviv District  Eilat  Haifa  \
# 0       NaN       NaN     NaN        NaN                NaN  360.0    NaN
# 1     260.0     230.0    60.0      135.0              101.0   30.0  336.0
# 2     260.0     230.0    60.0      157.0              315.0   30.0  336.0
# 3     260.0     231.0    60.0      157.0              307.0   30.0  336.0
# 4     260.0     233.0    60.0      157.0              294.0   30.0  336.0
#
#    Nahariyya  Jerusalem
# 0        NaN        NaN
# 1      336.0      329.0
# 2      336.0      329.0
# 3      336.0      329.0
# 4      336.0      329.0
#
# [5 rows x 37 columns]
#
# Weather Description Data:
#               datetime      Vancouver          Portland San Francisco  \
# 0  2012-10-01 12:00:00            NaN               NaN           NaN
# 1  2012-10-01 13:00:00           mist  scattered clouds    light rain
# 2  2012-10-01 14:00:00  broken clouds  scattered clouds  sky is clear
# 3  2012-10-01 15:00:00  broken clouds  scattered clouds  sky is clear
# 4  2012-10-01 16:00:00  broken clouds  scattered clouds  sky is clear
#
#         Seattle   Los Angeles     San Diego     Las Vegas       Phoenix  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  sky is clear          mist  sky is clear  sky is clear  sky is clear
# 2  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
# 3  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
# 4  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
#
#     Albuquerque  ...   Philadelphia    New York         Montreal  \
# 0           NaN  ...            NaN         NaN              NaN
# 1  sky is clear  ...  broken clouds  few clouds  overcast clouds
# 2  sky is clear  ...  broken clouds  few clouds     sky is clear
# 3  sky is clear  ...  broken clouds  few clouds     sky is clear
# 4  sky is clear  ...  broken clouds  few clouds     sky is clear
#
#          Boston        Beersheba Tel Aviv District          Eilat  \
# 0           NaN              NaN               NaN           haze
# 1  sky is clear     sky is clear      sky is clear           haze
# 2    few clouds     sky is clear      sky is clear  broken clouds
# 3    few clouds  overcast clouds      sky is clear  broken clouds
# 4    few clouds  overcast clouds      sky is clear  broken clouds
#
#              Haifa        Nahariyya        Jerusalem
# 0              NaN              NaN              NaN
# 1     sky is clear     sky is clear     sky is clear
# 2  overcast clouds     sky is clear  overcast clouds
# 3  overcast clouds  overcast clouds  overcast clouds
# 4  overcast clouds  overcast clouds  overcast clouds
#
# [5 rows x 37 columns]

# %%
# DATA EXPLORATION OF FILES

dataframes = [temperature_df, humidity_df, pressure_df, wind_speed_df, wind_direction_df, weather_description_df]
names = ["Temperature", "Humidity", "Pressure", "Wind Speed", "Wind Direction", "Weather Description"]

# Check basic information about each dataset
for df, name in zip(dataframes, names):
    print(f"\n{name} Data Info:")
    print(df.info())
    print(f"\n{name} Data Missing Values:")
    print(df.isnull().sum())
    print(f"\n{name} Data Description:")
    print(df.describe())
# Out:
# Temperature Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   datetime           45253 non-null  object
#  1   Vancouver          44458 non-null  float64
#  2   Portland           45252 non-null  float64
#  3   San Francisco      44460 non-null  float64
#  4   Seattle            45250 non-null  float64
#  5   Los Angeles        45250 non-null  float64
#  6   San Diego          45252 non-null  float64
#  7   Las Vegas          45252 non-null  float64
#  8   Phoenix            45250 non-null  float64
#  9   Albuquerque        45252 non-null  float64
#  10  Denver             45252 non-null  float64
#  11  San Antonio        45252 non-null  float64
#  12  Dallas             45249 non-null  float64
#  13  Houston            45250 non-null  float64
#  14  Kansas City        45252 non-null  float64
#  15  Minneapolis        45240 non-null  float64
#  16  Saint Louis        45252 non-null  float64
#  17  Chicago            45250 non-null  float64
#  18  Nashville          45251 non-null  float64
#  19  Indianapolis       45246 non-null  float64
#  20  Atlanta            45247 non-null  float64
#  21  Detroit            45252 non-null  float64
#  22  Jacksonville       45252 non-null  float64
#  23  Charlotte          45250 non-null  float64
#  24  Miami              44448 non-null  float64
#  25  Pittsburgh         45250 non-null  float64
#  26  Toronto            45252 non-null  float64
#  27  Philadelphia       45250 non-null  float64
#  28  New York           44460 non-null  float64
#  29  Montreal           45250 non-null  float64
#  30  Boston             45250 non-null  float64
#  31  Beersheba          44455 non-null  float64
#  32  Tel Aviv District  44460 non-null  float64
#  33  Eilat              44461 non-null  float64
#  34  Haifa              44455 non-null  float64
#  35  Nahariyya          44456 non-null  float64
#  36  Jerusalem          44460 non-null  float64
# dtypes: float64(36), object(1)
# memory usage: 12.8+ MB
# None
#
# Temperature Data Missing Values:
# datetime               0
# Vancouver            795
# Portland               1
# San Francisco        793
# Seattle                3
# Los Angeles            3
# San Diego              1
# Las Vegas              1
# Phoenix                3
# Albuquerque            1
# Denver                 1
# San Antonio            1
# Dallas                 4
# Houston                3
# Kansas City            1
# Minneapolis           13
# Saint Louis            1
# Chicago                3
# Nashville              2
# Indianapolis           7
# Atlanta                6
# Detroit                1
# Jacksonville           1
# Charlotte              3
# Miami                805
# Pittsburgh             3
# Toronto                1
# Philadelphia           3
# New York             793
# Montreal               3
# Boston                 3
# Beersheba            798
# Tel Aviv District    793
# Eilat                792
# Haifa                798
# Nahariyya            797
# Jerusalem            793
# dtype: int64
#
# Temperature Data Description:
#           Vancouver      Portland  San Francisco       Seattle   Los Angeles  \
# count  44458.000000  45252.000000   44460.000000  45250.000000  45250.000000
# mean     283.862654    284.992929     288.155821    284.409626    290.846116
# std        6.640131      7.452438       5.332862      6.547986      6.460823
# min      245.150000    262.370000     272.300000    263.780000    266.503667
# 25%      279.160000    279.850000     284.670000    279.830000    286.380000
# 50%      283.450000    284.320000     287.610000    283.940000    290.530000
# 75%      288.600785    289.451750     291.015167    288.530000    295.080000
# max      307.000000    312.520000     313.620000    307.300000    315.470000
#
#           San Diego     Las Vegas       Phoenix   Albuquerque        Denver  \
# count  45252.000000  45252.000000  45250.000000  45252.000000  45252.000000
# mean     290.215044    292.424887    295.493358    285.617856    282.839407
# std        5.889992     10.829522      9.916743      9.853484     10.673464
# min      265.783333    260.561333    266.059000    255.042333    247.727667
# 25%      286.254750    283.920000    287.680000    277.970000    275.060000
# 50%      290.118750    292.027486    295.586667    286.120000    282.970667
# 75%      294.107542    300.835000    303.050000    292.835643    290.680000
# max      313.360000    318.640000    321.220000    312.710000    313.750000
#
#        ...  Philadelphia      New York      Montreal        Boston  \
# count  ...  45250.000000  44460.000000  45250.000000  45250.000000
# mean   ...    285.374168    285.400406    280.343010    283.779823
# std    ...     10.242377     10.220932     11.953626      9.802499
# min    ...    250.390000    250.774000    243.300000    249.540000
# 25%    ...    277.350636    277.370000    271.971750    276.090000
# 50%    ...    285.927583    285.870000    281.109000    284.133250
# 75%    ...    293.796000    293.760000    290.369583    291.620000
# max    ...    308.000000    310.240000    307.880000    308.000000
#
#           Beersheba  Tel Aviv District         Eilat         Haifa  \
# count  44455.000000       44460.000000  44461.000000  44455.000000
# mean     291.521986         294.512307    296.497276    295.266398
# std        7.821815           6.676412      8.852984      6.324566
# min      272.179000         271.049000    271.150000    271.150000
# 25%      285.366623         289.450000    289.734000    290.467333
# 50%      290.932667         294.900000    296.150000    294.820000
# 75%      297.270000         299.800000    303.150000    299.660000
# max      314.820000         320.930000    320.150000    320.930000
#
#           Nahariyya     Jerusalem
# count  44456.000000  44460.000000
# mean     294.094803    293.184253
# std        6.304118      7.093583
# min      268.682000    272.974000
# 25%      289.881833    287.524279
# 50%      294.150000    292.996000
# 75%      298.930000    299.150000
# max      313.150000    317.040000
#
# [8 rows x 36 columns]
#
# Humidity Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   datetime           45253 non-null  object
#  1   Vancouver          43427 non-null  float64
#  2   Portland           44804 non-null  float64
#  3   San Francisco      44311 non-null  float64
#  4   Seattle            44964 non-null  float64
#  5   Los Angeles        45101 non-null  float64
#  6   San Diego          44909 non-null  float64
#  7   Las Vegas          44411 non-null  float64
#  8   Phoenix            43945 non-null  float64
#  9   Albuquerque        44543 non-null  float64
#  10  Denver             43445 non-null  float64
#  11  San Antonio        44689 non-null  float64
#  12  Dallas             44934 non-null  float64
#  13  Houston            45132 non-null  float64
#  14  Kansas City        44741 non-null  float64
#  15  Minneapolis        44743 non-null  float64
#  16  Saint Louis        43964 non-null  float64
#  17  Chicago            44144 non-null  float64
#  18  Nashville          44686 non-null  float64
#  19  Indianapolis       44558 non-null  float64
#  20  Atlanta            44831 non-null  float64
#  21  Detroit            44391 non-null  float64
#  22  Jacksonville       45044 non-null  float64
#  23  Charlotte          44664 non-null  float64
#  24  Miami              44166 non-null  float64
#  25  Pittsburgh         44731 non-null  float64
#  26  Toronto            44525 non-null  float64
#  27  Philadelphia       44629 non-null  float64
#  28  New York           43629 non-null  float64
#  29  Montreal           43557 non-null  float64
#  30  Boston             44804 non-null  float64
#  31  Beersheba          44394 non-null  float64
#  32  Tel Aviv District  44140 non-null  float64
#  33  Eilat              44283 non-null  float64
#  34  Haifa              44435 non-null  float64
#  35  Nahariyya          44436 non-null  float64
#  36  Jerusalem          44347 non-null  float64
# dtypes: float64(36), object(1)
# memory usage: 12.8+ MB
# None
#
# Humidity Data Missing Values:
# datetime                0
# Vancouver            1826
# Portland              449
# San Francisco         942
# Seattle               289
# Los Angeles           152
# San Diego             344
# Las Vegas             842
# Phoenix              1308
# Albuquerque           710
# Denver               1808
# San Antonio           564
# Dallas                319
# Houston               121
# Kansas City           512
# Minneapolis           510
# Saint Louis          1289
# Chicago              1109
# Nashville             567
# Indianapolis          695
# Atlanta               422
# Detroit               862
# Jacksonville          209
# Charlotte             589
# Miami                1087
# Pittsburgh            522
# Toronto               728
# Philadelphia          624
# New York             1624
# Montreal             1696
# Boston                449
# Beersheba             859
# Tel Aviv District    1113
# Eilat                 970
# Haifa                 818
# Nahariyya             817
# Jerusalem             906
# dtype: int64
#
# Humidity Data Description:
#           Vancouver      Portland  San Francisco       Seattle   Los Angeles  \
# count  43427.000000  44804.000000   44311.000000  44964.000000  45101.000000
# mean      81.895480     74.697616      76.875042     77.159038     62.773841
# std       14.522221     19.042656      17.396016     18.147464     21.818042
# min       12.000000     10.000000       6.000000     13.000000      5.000000
# 25%       73.000000     63.000000      68.000000     66.000000     48.000000
# 50%       86.000000     80.000000      81.000000     81.000000     66.000000
# 75%       93.000000     90.000000      89.000000     93.000000     81.000000
# max      100.000000    100.000000     100.000000    100.000000    100.000000
#
#           San Diego     Las Vegas       Phoenix   Albuquerque        Denver  \
# count  44909.000000  44411.000000  43945.000000  44543.000000  43445.000000
# mean      67.784809     31.937831     37.484424     45.186157     53.022557
# std       19.419307     20.041855     21.662728     23.336546     23.905392
# min        5.000000      5.000000      5.000000      5.000000      5.000000
# 25%       56.000000     16.000000     21.000000     26.000000     33.000000
# 50%       71.000000     27.000000     32.000000     42.000000     52.000000
# 75%       82.000000     43.000000     50.000000     63.000000     73.000000
# max      100.000000    100.000000    100.000000    100.000000    100.000000
#
#        ...  Philadelphia      New York      Montreal        Boston  \
# count  ...  44629.000000  43629.000000  43557.000000  44804.000000
# mean   ...     68.017769     66.642417     71.861538     77.375301
# std    ...     18.790524     19.874727     16.825027     18.750190
# min    ...     10.000000     10.000000      7.000000     11.000000
# 25%    ...     54.000000     51.000000     60.000000     65.000000
# 50%    ...     68.000000     68.000000     74.000000     81.000000
# 75%    ...     84.000000     83.000000     86.000000     93.000000
# max    ...    100.000000    100.000000    100.000000    100.000000
#
#           Beersheba  Tel Aviv District         Eilat         Haifa  \
# count  44394.000000       44140.000000  44283.000000  44435.000000
# mean      70.604857          66.861509     53.155184     79.800383
# std       21.321606          16.464177     27.305008     23.051692
# min        5.000000           5.000000      5.000000      5.000000
# 25%       54.000000          58.000000     31.000000     63.000000
# 50%       77.000000          69.000000     48.000000     89.000000
# 75%       88.000000          78.000000     75.000000    100.000000
# max      100.000000         100.000000    100.000000    100.000000
#
#           Nahariyya     Jerusalem
# count  44436.000000  44347.000000
# mean      78.606760     68.732293
# std       23.682244     19.273881
# min        5.000000      5.000000
# 25%       61.000000     56.000000
# 50%       87.000000     70.000000
# 75%      100.000000     83.000000
# max      100.000000    100.000000
#
# [8 rows x 36 columns]
#
# Pressure Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   datetime           45253 non-null  object
#  1   Vancouver          41019 non-null  float64
#  2   Portland           45249 non-null  float64
#  3   San Francisco      44438 non-null  float64
#  4   Seattle            45240 non-null  float64
#  5   Los Angeles        45001 non-null  float64
#  6   San Diego          45078 non-null  float64
#  7   Las Vegas          45165 non-null  float64
#  8   Phoenix            44659 non-null  float64
#  9   Albuquerque        44797 non-null  float64
#  10  Denver             44710 non-null  float64
#  11  San Antonio        45236 non-null  float64
#  12  Dallas             45193 non-null  float64
#  13  Houston            45244 non-null  float64
#  14  Kansas City        45132 non-null  float64
#  15  Minneapolis        45236 non-null  float64
#  16  Saint Louis        45185 non-null  float64
#  17  Chicago            44528 non-null  float64
#  18  Nashville          45106 non-null  float64
#  19  Indianapolis       44964 non-null  float64
#  20  Atlanta            45204 non-null  float64
#  21  Detroit            45248 non-null  float64
#  22  Jacksonville       45238 non-null  float64
#  23  Charlotte          45250 non-null  float64
#  24  Miami              44459 non-null  float64
#  25  Pittsburgh         45207 non-null  float64
#  26  Toronto            45078 non-null  float64
#  27  Philadelphia       45249 non-null  float64
#  28  New York           44212 non-null  float64
#  29  Montreal           44259 non-null  float64
#  30  Boston             45246 non-null  float64
#  31  Beersheba          44447 non-null  float64
#  32  Tel Aviv District  44323 non-null  float64
#  33  Eilat              44461 non-null  float64
#  34  Haifa              44455 non-null  float64
#  35  Nahariyya          44458 non-null  float64
#  36  Jerusalem          44454 non-null  float64
# dtypes: float64(36), object(1)
# memory usage: 12.8+ MB
# None
#
# Pressure Data Missing Values:
# datetime                0
# Vancouver            4234
# Portland                4
# San Francisco         815
# Seattle                13
# Los Angeles           252
# San Diego             175
# Las Vegas              88
# Phoenix               594
# Albuquerque           456
# Denver                543
# San Antonio            17
# Dallas                 60
# Houston                 9
# Kansas City           121
# Minneapolis            17
# Saint Louis            68
# Chicago               725
# Nashville             147
# Indianapolis          289
# Atlanta                49
# Detroit                 5
# Jacksonville           15
# Charlotte               3
# Miami                 794
# Pittsburgh             46
# Toronto               175
# Philadelphia            4
# New York             1041
# Montreal              994
# Boston                  7
# Beersheba             806
# Tel Aviv District     930
# Eilat                 792
# Haifa                 798
# Nahariyya             795
# Jerusalem             799
# dtype: int64
#
# Pressure Data Description:
#           Vancouver      Portland  San Francisco       Seattle   Los Angeles  \
# count  41019.000000  45249.000000   44438.000000  45240.000000  45001.000000
# mean    1018.130915   1019.268382    1018.843872   1021.001216   1015.912735
# std       15.792425      9.943136       7.333477      9.737187     11.289701
# min      807.000000    968.000000     985.000000    980.000000    886.000000
# 25%     1012.000000   1014.000000    1014.000000   1015.000000   1013.000000
# 50%     1017.000000   1019.000000    1018.000000   1020.000000   1016.000000
# 75%     1022.000000   1025.000000    1023.000000   1027.000000   1021.000000
# max     1100.000000   1056.000000    1044.000000   1058.000000   1044.000000
#
#           San Diego     Las Vegas       Phoenix   Albuquerque        Denver  \
# count  45078.000000  45165.000000  44659.000000  44797.000000  44710.000000
# mean    1017.524491   1013.659648   1013.297342   1012.292185   1011.976359
# std        8.554904     18.893592     11.988782     39.049838     41.343487
# min      964.000000    901.000000    884.000000    810.000000    800.000000
# 25%     1014.000000   1010.000000   1009.000000   1015.000000   1014.000000
# 50%     1017.000000   1015.000000   1014.000000   1021.000000   1020.000000
# 75%     1022.000000   1022.000000   1020.000000   1025.000000   1025.000000
# max     1043.000000   1047.000000   1076.000000   1054.000000   1089.000000
#
#        ...  Philadelphia      New York      Montreal        Boston  \
# count  ...  45249.000000  44212.000000  44259.000000  45246.000000
# mean   ...   1020.250193   1017.018977   1016.424953   1019.861314
# std    ...      9.507596     10.125738      9.534390      9.548220
# min    ...    824.000000    959.000000    822.000000    978.000000
# 25%    ...   1014.000000   1012.000000   1011.000000   1014.000000
# 50%    ...   1019.000000   1017.000000   1016.000000   1019.000000
# 75%    ...   1026.000000   1023.000000   1022.000000   1026.000000
# max    ...   1059.000000   1052.000000   1054.000000   1054.000000
#
#           Beersheba  Tel Aviv District         Eilat         Haifa  \
# count  44447.000000       44323.000000  44461.000000  44455.000000
# mean     991.172565        1013.815468   1002.039248   1017.550804
# std       14.165100           6.476167     22.610353      7.500017
# min      957.000000         929.000000    936.000000    999.000000
# 25%      985.000000        1010.000000   1002.000000   1012.000000
# 50%      988.000000        1013.000000   1010.000000   1017.000000
# 75%      994.000000        1018.000000   1016.000000   1024.000000
# max     1099.000000        1039.000000   1040.000000   1042.000000
#
#           Nahariyya     Jerusalem
# count  44458.000000  44454.000000
# mean    1015.901997   1011.034980
# std       10.238495     12.951002
# min      980.000000    981.000000
# 25%     1011.000000   1002.000000
# 50%     1017.000000   1012.000000
# 75%     1023.000000   1020.000000
# max     1042.000000   1042.000000
#
# [8 rows x 36 columns]
#
# Wind Speed Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   datetime           45253 non-null  object
#  1   Vancouver          44458 non-null  float64
#  2   Portland           45252 non-null  float64
#  3   San Francisco      44459 non-null  float64
#  4   Seattle            45252 non-null  float64
#  5   Los Angeles        45252 non-null  float64
#  6   San Diego          45252 non-null  float64
#  7   Las Vegas          45238 non-null  float64
#  8   Phoenix            45251 non-null  float64
#  9   Albuquerque        45249 non-null  float64
#  10  Denver             45251 non-null  float64
#  11  San Antonio        45252 non-null  float64
#  12  Dallas             45251 non-null  float64
#  13  Houston            45250 non-null  float64
#  14  Kansas City        45252 non-null  float64
#  15  Minneapolis        45250 non-null  float64
#  16  Saint Louis        45252 non-null  float64
#  17  Chicago            45252 non-null  float64
#  18  Nashville          45250 non-null  float64
#  19  Indianapolis       45252 non-null  float64
#  20  Atlanta            45252 non-null  float64
#  21  Detroit            45252 non-null  float64
#  22  Jacksonville       45252 non-null  float64
#  23  Charlotte          45251 non-null  float64
#  24  Miami              44458 non-null  float64
#  25  Pittsburgh         45252 non-null  float64
#  26  Toronto            45252 non-null  float64
#  27  Philadelphia       45251 non-null  float64
#  28  New York           44460 non-null  float64
#  29  Montreal           45252 non-null  float64
#  30  Boston             45252 non-null  float64
#  31  Beersheba          44460 non-null  float64
#  32  Tel Aviv District  44459 non-null  float64
#  33  Eilat              44461 non-null  float64
#  34  Haifa              44458 non-null  float64
#  35  Nahariyya          44459 non-null  float64
#  36  Jerusalem          44459 non-null  float64
# dtypes: float64(36), object(1)
# memory usage: 12.8+ MB
# None
#
# Wind Speed Data Missing Values:
# datetime               0
# Vancouver            795
# Portland               1
# San Francisco        794
# Seattle                1
# Los Angeles            1
# San Diego              1
# Las Vegas             15
# Phoenix                2
# Albuquerque            4
# Denver                 2
# San Antonio            1
# Dallas                 2
# Houston                3
# Kansas City            1
# Minneapolis            3
# Saint Louis            1
# Chicago                1
# Nashville              3
# Indianapolis           1
# Atlanta                1
# Detroit                1
# Jacksonville           1
# Charlotte              2
# Miami                795
# Pittsburgh             1
# Toronto                1
# Philadelphia           2
# New York             793
# Montreal               1
# Boston                 1
# Beersheba            793
# Tel Aviv District    794
# Eilat                792
# Haifa                795
# Nahariyya            794
# Jerusalem            794
# dtype: int64
#
# Wind Speed Data Description:
#           Vancouver      Portland  San Francisco       Seattle   Los Angeles  \
# count  44458.000000  45252.000000   44459.000000  45252.000000  45252.000000
# mean       2.432746      2.050738       2.786702      2.118116      1.219548
# std        2.004636      1.840815       2.284011      1.629988      1.434552
# min        0.000000      0.000000       0.000000      0.000000      0.000000
# 25%        1.000000      1.000000       1.000000      1.000000      0.000000
# 50%        2.000000      1.000000       2.000000      2.000000      1.000000
# 75%        4.000000      3.000000       4.000000      3.000000      2.000000
# max       25.000000     17.000000      43.000000     24.000000     17.000000
#
#           San Diego     Las Vegas       Phoenix   Albuquerque        Denver  \
# count  45252.000000  45238.000000  45251.000000  45249.000000  45251.000000
# mean       1.751458      2.463482      1.909063      2.763685      2.438996
# std        1.489450      2.318692      1.623629      2.300933      2.158956
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      1.000000      1.000000      1.000000      1.000000
# 50%        1.000000      2.000000      1.000000      2.000000      2.000000
# 75%        2.000000      3.000000      3.000000      4.000000      3.000000
# max       30.000000     19.000000     48.000000     22.000000     22.000000
#
#        ...  Philadelphia      New York      Montreal        Boston  \
# count  ...  45251.000000  44460.000000  45252.000000  45252.000000
# mean   ...      2.643212      3.210954      3.831897      3.380889
# std    ...      1.836347      2.189716      2.483430      2.277266
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      1.000000      2.000000      2.000000      2.000000
# 50%    ...      2.000000      3.000000      3.000000      3.000000
# 75%    ...      3.000000      4.000000      5.000000      5.000000
# max    ...     31.000000     25.000000     24.000000     20.000000
#
#           Beersheba  Tel Aviv District         Eilat         Haifa  \
# count  44460.000000       44459.000000  44461.000000  44458.000000
# mean       1.989339           2.722306      3.452576      3.299406
# std        1.462556           1.923380      2.323312      2.177502
# min        0.000000           0.000000      0.000000      0.000000
# 25%        1.000000           1.000000      1.000000      2.000000
# 50%        1.000000           2.000000      3.000000      3.000000
# 75%        3.000000           4.000000      5.000000      4.000000
# max       14.000000          49.000000     44.000000     19.000000
#
#           Nahariyya     Jerusalem
# count  44459.000000  44459.000000
# mean       3.024292      1.880047
# std        2.124482      1.712640
# min        0.000000      0.000000
# 25%        1.000000      1.000000
# 50%        3.000000      1.000000
# 75%        4.000000      2.000000
# max       17.000000     49.000000
#
# [8 rows x 36 columns]
#
# Wind Direction Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   datetime           45253 non-null  object
#  1   Vancouver          44458 non-null  float64
#  2   Portland           45252 non-null  float64
#  3   San Francisco      44459 non-null  float64
#  4   Seattle            45252 non-null  float64
#  5   Los Angeles        45252 non-null  float64
#  6   San Diego          45252 non-null  float64
#  7   Las Vegas          45248 non-null  float64
#  8   Phoenix            45252 non-null  float64
#  9   Albuquerque        45252 non-null  float64
#  10  Denver             45252 non-null  float64
#  11  San Antonio        45252 non-null  float64
#  12  Dallas             45252 non-null  float64
#  13  Houston            45251 non-null  float64
#  14  Kansas City        45252 non-null  float64
#  15  Minneapolis        45252 non-null  float64
#  16  Saint Louis        45252 non-null  float64
#  17  Chicago            45252 non-null  float64
#  18  Nashville          45251 non-null  float64
#  19  Indianapolis       45252 non-null  float64
#  20  Atlanta            45252 non-null  float64
#  21  Detroit            45252 non-null  float64
#  22  Jacksonville       45248 non-null  float64
#  23  Charlotte          45252 non-null  float64
#  24  Miami              44458 non-null  float64
#  25  Pittsburgh         45252 non-null  float64
#  26  Toronto            45252 non-null  float64
#  27  Philadelphia       45252 non-null  float64
#  28  New York           44460 non-null  float64
#  29  Montreal           45252 non-null  float64
#  30  Boston             45252 non-null  float64
#  31  Beersheba          44460 non-null  float64
#  32  Tel Aviv District  44460 non-null  float64
#  33  Eilat              44456 non-null  float64
#  34  Haifa              44460 non-null  float64
#  35  Nahariyya          44460 non-null  float64
#  36  Jerusalem          44460 non-null  float64
# dtypes: float64(36), object(1)
# memory usage: 12.8+ MB
# None
#
# Wind Direction Data Missing Values:
# datetime               0
# Vancouver            795
# Portland               1
# San Francisco        794
# Seattle                1
# Los Angeles            1
# San Diego              1
# Las Vegas              5
# Phoenix                1
# Albuquerque            1
# Denver                 1
# San Antonio            1
# Dallas                 1
# Houston                2
# Kansas City            1
# Minneapolis            1
# Saint Louis            1
# Chicago                1
# Nashville              2
# Indianapolis           1
# Atlanta                1
# Detroit                1
# Jacksonville           5
# Charlotte              1
# Miami                795
# Pittsburgh             1
# Toronto                1
# Philadelphia           1
# New York             793
# Montreal               1
# Boston                 1
# Beersheba            793
# Tel Aviv District    793
# Eilat                797
# Haifa                793
# Nahariyya            793
# Jerusalem            793
# dtype: int64
#
# Wind Direction Data Description:
#           Vancouver      Portland  San Francisco       Seattle   Los Angeles  \
# count  44458.000000  45252.000000   44459.000000  45252.000000  45252.000000
# mean     159.892978    189.900071     209.299489    161.380226    139.549611
# std       98.163221    102.873761      95.589055    103.206816    105.591486
# min        0.000000      0.000000       0.000000      0.000000      0.000000
# 25%       80.000000    107.000000     160.000000     70.000000     29.000000
# 50%      140.000000    198.000000     232.000000    175.000000    140.000000
# 75%      236.000000    289.000000     280.000000    218.000000    230.000000
# max      360.000000    360.000000     360.000000    360.000000    360.000000
#
#           San Diego     Las Vegas       Phoenix   Albuquerque        Denver  \
# count  45252.000000  45248.000000  45252.000000  45252.000000  45252.000000
# mean     199.212852    176.320987    168.564351    199.878458    184.769005
# std      106.350252    106.902903    107.533094    104.462490    104.705030
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      102.000000     94.000000     74.000000    125.000000    100.000000
# 50%      230.000000    180.000000    180.000000    210.000000    200.000000
# 75%      290.000000    255.000000    250.000000    292.000000    268.000000
# max      360.000000    360.000000    360.000000    360.000000    360.000000
#
#        ...  Philadelphia      New York      Montreal        Boston  \
# count  ...  45252.000000  44460.000000  45252.000000  45252.000000
# mean   ...    202.947008    196.250247    190.133541    184.915562
# std    ...    102.323689    107.433676     99.033739    107.763589
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...    120.000000    104.000000    111.000000     80.000000
# 50%    ...    224.000000    220.000000    220.000000    210.000000
# 75%    ...    289.000000    289.000000    260.000000    272.000000
# max    ...    360.000000    360.000000    360.000000    360.000000
#
#           Beersheba  Tel Aviv District         Eilat         Haifa  \
# count  44460.000000       44460.000000  44456.000000  44460.000000
# mean     218.891206         171.459199    204.244691    196.070558
# std      102.304924         121.843329    144.891439    112.498247
# min        0.000000           0.000000      0.000000      0.000000
# 25%      112.000000          40.000000     40.000000    106.750000
# 50%      252.000000         184.000000    264.000000    224.000000
# 75%      309.000000         280.000000    345.000000    291.000000
# max      359.000000         360.000000    360.000000    360.000000
#
#           Nahariyya     Jerusalem
# count  44460.000000  44460.000000
# mean     194.901552    185.095592
# std      111.983576    117.733600
# min        0.000000      0.000000
# 25%      102.000000     68.000000
# 50%      223.000000    230.000000
# 75%      290.000000    287.000000
# max      360.000000    360.000000
#
# [8 rows x 36 columns]
#
# Weather Description Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   datetime           45253 non-null  object
#  1   Vancouver          44460 non-null  object
#  2   Portland           45252 non-null  object
#  3   San Francisco      44460 non-null  object
#  4   Seattle            45252 non-null  object
#  5   Los Angeles        45252 non-null  object
#  6   San Diego          45252 non-null  object
#  7   Las Vegas          45252 non-null  object
#  8   Phoenix            45252 non-null  object
#  9   Albuquerque        45252 non-null  object
#  10  Denver             45252 non-null  object
#  11  San Antonio        45252 non-null  object
#  12  Dallas             45252 non-null  object
#  13  Houston            45252 non-null  object
#  14  Kansas City        45252 non-null  object
#  15  Minneapolis        45252 non-null  object
#  16  Saint Louis        45252 non-null  object
#  17  Chicago            45252 non-null  object
#  18  Nashville          45252 non-null  object
#  19  Indianapolis       45252 non-null  object
#  20  Atlanta            45252 non-null  object
#  21  Detroit            45252 non-null  object
#  22  Jacksonville       45252 non-null  object
#  23  Charlotte          45252 non-null  object
#  24  Miami              44460 non-null  object
#  25  Pittsburgh         45252 non-null  object
#  26  Toronto            45252 non-null  object
#  27  Philadelphia       45252 non-null  object
#  28  New York           44460 non-null  object
#  29  Montreal           45252 non-null  object
#  30  Boston             45252 non-null  object
#  31  Beersheba          44460 non-null  object
#  32  Tel Aviv District  44460 non-null  object
#  33  Eilat              44461 non-null  object
#  34  Haifa              44460 non-null  object
#  35  Nahariyya          44460 non-null  object
#  36  Jerusalem          44460 non-null  object
# dtypes: object(37)
# memory usage: 12.8+ MB
# None
#
# Weather Description Data Missing Values:
# datetime               0
# Vancouver            793
# Portland               1
# San Francisco        793
# Seattle                1
# Los Angeles            1
# San Diego              1
# Las Vegas              1
# Phoenix                1
# Albuquerque            1
# Denver                 1
# San Antonio            1
# Dallas                 1
# Houston                1
# Kansas City            1
# Minneapolis            1
# Saint Louis            1
# Chicago                1
# Nashville              1
# Indianapolis           1
# Atlanta                1
# Detroit                1
# Jacksonville           1
# Charlotte              1
# Miami                793
# Pittsburgh             1
# Toronto                1
# Philadelphia           1
# New York             793
# Montreal               1
# Boston                 1
# Beersheba            793
# Tel Aviv District    793
# Eilat                792
# Haifa                793
# Nahariyya            793
# Jerusalem            793
# dtype: int64
#
# Weather Description Data Description:
#                    datetime     Vancouver      Portland San Francisco  \
# count                 45253         44460         45252         44460
# unique                45253            37            24            28
# top     2012-10-01 12:00:00  sky is clear  sky is clear  sky is clear
# freq                      1         12805         11725         12654
#
#              Seattle   Los Angeles     San Diego     Las Vegas       Phoenix  \
# count          45252         45252         45252         45252         45252
# unique            29            25            22            23            26
# top     sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
# freq           12801         26136         14829         35090         30303
#
#          Albuquerque  ...  Philadelphia      New York       Montreal  \
# count          45252  ...         45252         44460          45252
# unique            37  ...            30            36             37
# top     sky is clear  ...  sky is clear  sky is clear  broken clouds
# freq           18344  ...         14919         11601           8151
#
#               Boston     Beersheba Tel Aviv District         Eilat  \
# count          45252         44460             44460         44461
# unique            27             8                26            20
# top     sky is clear  sky is clear      sky is clear  sky is clear
# freq           17444         29442             21739         37320
#
#                Haifa     Nahariyya     Jerusalem
# count          44460         44460         44460
# unique            20            20            23
# top     sky is clear  sky is clear  sky is clear
# freq           25587         25516         26934
#
# [4 rows x 37 columns]

# %%
# Finding Correlations
correlation_matrix = numeric_df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# HANDLING THE MISSING VALUES

# Fill missing values for each DataFrame using both forward and backward fill
temperature_df.fillna(method='ffill', inplace=True)
temperature_df.fillna(method='bfill', inplace=True)
humidity_df.fillna(method='ffill', inplace=True)
humidity_df.fillna(method='bfill', inplace=True)
pressure_df.fillna(method='ffill', inplace=True)
pressure_df.fillna(method='bfill', inplace=True)
wind_speed_df.fillna(method='ffill', inplace=True)
wind_speed_df.fillna(method='bfill', inplace=True)
wind_direction_df.fillna(method='ffill', inplace=True)
wind_direction_df.fillna(method='bfill', inplace=True)
weather_description_df.fillna(method='ffill', inplace=True)
weather_description_df.fillna(method='bfill', inplace=True)

# Display summary of missing values after filling
for df, name in zip(dataframes, names):
    print(f"\n{name} Data Missing Values After Filling:")
    print(df.isnull().sum())
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/3390741008.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   temperature_df.fillna(method='ffill', inplace=True)
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/3390741008.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   temperature_df.fillna(method='bfill', inplace=True)
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/3390741008.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   humidity_df.fillna(method='ffill', inplace=True)
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/3390741008.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   humidity_df.fillna(method='bfill', inplace=True)
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/3390741008.py:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pressure_df.fillna(method='ffill', inplace=True)
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/3390741008.py:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pressure_df.fillna(method='bfill', inplace=True)
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/3390741008.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wind_speed_df.fillna(method='ffill', inplace=True)
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/3390741008.py:9: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wind_speed_df.fillna(method='bfill', inplace=True)
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/3390741008.py:10: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wind_direction_df.fillna(method='ffill', inplace=True)
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/3390741008.py:11: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wind_direction_df.fillna(method='bfill', inplace=True)
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/3390741008.py:12: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   weather_description_df.fillna(method='ffill', inplace=True)
# Temperature Data Missing Values After Filling:
# datetime             0
# Vancouver            0
# Portland             0
# San Francisco        0
# Seattle              0
# Los Angeles          0
# San Diego            0
# Las Vegas            0
# Phoenix              0
# Albuquerque          0
# Denver               0
# San Antonio          0
# Dallas               0
# Houston              0
# Kansas City          0
# Minneapolis          0
# Saint Louis          0
# Chicago              0
# Nashville            0
# Indianapolis         0
# Atlanta              0
# Detroit              0
# Jacksonville         0
# Charlotte            0
# Miami                0
# Pittsburgh           0
# Toronto              0
# Philadelphia         0
# New York             0
# Montreal             0
# Boston               0
# Beersheba            0
# Tel Aviv District    0
# Eilat                0
# Haifa                0
# Nahariyya            0
# Jerusalem            0
# dtype: int64
#
# Humidity Data Missing Values After Filling:
# datetime             0
# Vancouver            0
# Portland             0
# San Francisco        0
# Seattle              0
# Los Angeles          0
# San Diego            0
# Las Vegas            0
# Phoenix              0
# Albuquerque          0
# Denver               0
# San Antonio          0
# Dallas               0
# Houston              0
# Kansas City          0
# Minneapolis          0
# Saint Louis          0
# Chicago              0
# Nashville            0
# Indianapolis         0
# Atlanta              0
# Detroit              0
# Jacksonville         0
# Charlotte            0
# Miami                0
# Pittsburgh           0
# Toronto              0
# Philadelphia         0
# New York             0
# Montreal             0
# Boston               0
# Beersheba            0
# Tel Aviv District    0
# Eilat                0
# Haifa                0
# Nahariyya            0
# Jerusalem            0
# dtype: int64
#
# Pressure Data Missing Values After Filling:
# datetime             0
# Vancouver            0
# Portland             0
# San Francisco        0
# Seattle              0
# Los Angeles          0
# San Diego            0
# Las Vegas            0
# Phoenix              0
# Albuquerque          0
# Denver               0
# San Antonio          0
# Dallas               0
# Houston              0
# Kansas City          0
# Minneapolis          0
# Saint Louis          0
# Chicago              0
# Nashville            0
# Indianapolis         0
# Atlanta              0
# Detroit              0
# Jacksonville         0
# Charlotte            0
# Miami                0
# Pittsburgh           0
# Toronto              0
# Philadelphia         0
# New York             0
# Montreal             0
# Boston               0
# Beersheba            0
# Tel Aviv District    0
# Eilat                0
# Haifa                0
# Nahariyya            0
# Jerusalem            0
# dtype: int64
#
# Wind Speed Data Missing Values After Filling:
# datetime             0
# Vancouver            0
# Portland             0
# San Francisco        0
# Seattle              0
# Los Angeles          0
# San Diego            0
# Las Vegas            0
# Phoenix              0
# Albuquerque          0
# Denver               0
# San Antonio          0
# Dallas               0
# Houston              0
# Kansas City          0
# Minneapolis          0
# Saint Louis          0
# Chicago              0
# Nashville            0
# Indianapolis         0
# Atlanta              0
# Detroit              0
# Jacksonville         0
# Charlotte            0
# Miami                0
# Pittsburgh           0
# Toronto              0
# Philadelphia         0
# New York             0
# Montreal             0
# Boston               0
# Beersheba            0
# Tel Aviv District    0
# Eilat                0
# Haifa                0
# Nahariyya            0
# Jerusalem            0
# dtype: int64
#
# Wind Direction Data Missing Values After Filling:
# datetime             0
# Vancouver            0
# Portland             0
# San Francisco        0
# Seattle              0
# Los Angeles          0
# San Diego            0
# Las Vegas            0
# Phoenix              0
# Albuquerque          0
# Denver               0
# San Antonio          0
# Dallas               0
# Houston              0
# Kansas City          0
# Minneapolis          0
# Saint Louis          0
# Chicago              0
# Nashville            0
# Indianapolis         0
# Atlanta              0
# Detroit              0
# Jacksonville         0
# Charlotte            0
# Miami                0
# Pittsburgh           0
# Toronto              0
# Philadelphia         0
# New York             0
# Montreal             0
# Boston               0
# Beersheba            0
# Tel Aviv District    0
# Eilat                0
# Haifa                0
# Nahariyya            0
# Jerusalem            0
# dtype: int64
#
# Weather Description Data Missing Values After Filling:
# datetime             0
# Vancouver            0
# Portland             0
# San Francisco        0
# Seattle              0
# Los Angeles          0
# San Diego            0
# Las Vegas            0
# Phoenix              0
# Albuquerque          0
# Denver               0
# San Antonio          0
# Dallas               0
# Houston              0
# Kansas City          0
# Minneapolis          0
# Saint Louis          0
# Chicago              0
# Nashville            0
# Indianapolis         0
# Atlanta              0
# Detroit              0
# Jacksonville         0
# Charlotte            0
# Miami                0
# Pittsburgh           0
# Toronto              0
# Philadelphia         0
# New York             0
# Montreal             0
# Boston               0
# Beersheba            0
# Tel Aviv District    0
# Eilat                0
# Haifa                0
# Nahariyya            0
# Jerusalem            0
# dtype: int64
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/3390741008.py:13: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   weather_description_df.fillna(method='bfill', inplace=True)

# %%
# Print column names of each DataFrame to understand their structure
for df, name in zip(dataframes, names):
    print(f"\n{name} DataFrame columns:")
    print(df.columns)
# Out:
# Temperature DataFrame columns:
# Index(['Vancouver', 'Portland', 'San Francisco', 'Seattle', 'Los Angeles',
#        'San Diego', 'Las Vegas', 'Phoenix', 'Albuquerque', 'Denver',
#        'San Antonio', 'Dallas', 'Houston', 'Kansas City', 'Minneapolis',
#        'Saint Louis', 'Chicago', 'Nashville', 'Indianapolis', 'Atlanta',
#        'Detroit', 'Jacksonville', 'Charlotte', 'Miami', 'Pittsburgh',
#        'Toronto', 'Philadelphia', 'New York', 'Montreal', 'Boston',
#        'Beersheba', 'Tel Aviv District', 'Eilat', 'Haifa', 'Nahariyya',
#        'Jerusalem'],
#       dtype='object')
#
# Humidity DataFrame columns:
# Index(['Vancouver', 'Portland', 'San Francisco', 'Seattle', 'Los Angeles',
#        'San Diego', 'Las Vegas', 'Phoenix', 'Albuquerque', 'Denver',
#        'San Antonio', 'Dallas', 'Houston', 'Kansas City', 'Minneapolis',
#        'Saint Louis', 'Chicago', 'Nashville', 'Indianapolis', 'Atlanta',
#        'Detroit', 'Jacksonville', 'Charlotte', 'Miami', 'Pittsburgh',
#        'Toronto', 'Philadelphia', 'New York', 'Montreal', 'Boston',
#        'Beersheba', 'Tel Aviv District', 'Eilat', 'Haifa', 'Nahariyya',
#        'Jerusalem'],
#       dtype='object')
#
# Pressure DataFrame columns:
# Index(['Vancouver', 'Portland', 'San Francisco', 'Seattle', 'Los Angeles',
#        'San Diego', 'Las Vegas', 'Phoenix', 'Albuquerque', 'Denver',
#        'San Antonio', 'Dallas', 'Houston', 'Kansas City', 'Minneapolis',
#        'Saint Louis', 'Chicago', 'Nashville', 'Indianapolis', 'Atlanta',
#        'Detroit', 'Jacksonville', 'Charlotte', 'Miami', 'Pittsburgh',
#        'Toronto', 'Philadelphia', 'New York', 'Montreal', 'Boston',
#        'Beersheba', 'Tel Aviv District', 'Eilat', 'Haifa', 'Nahariyya',
#        'Jerusalem'],
#       dtype='object')
#
# Wind Speed DataFrame columns:
# Index(['Vancouver', 'Portland', 'San Francisco', 'Seattle', 'Los Angeles',
#        'San Diego', 'Las Vegas', 'Phoenix', 'Albuquerque', 'Denver',
#        'San Antonio', 'Dallas', 'Houston', 'Kansas City', 'Minneapolis',
#        'Saint Louis', 'Chicago', 'Nashville', 'Indianapolis', 'Atlanta',
#        'Detroit', 'Jacksonville', 'Charlotte', 'Miami', 'Pittsburgh',
#        'Toronto', 'Philadelphia', 'New York', 'Montreal', 'Boston',
#        'Beersheba', 'Tel Aviv District', 'Eilat', 'Haifa', 'Nahariyya',
#        'Jerusalem'],
#       dtype='object')
#
# Wind Direction DataFrame columns:
# Index(['Vancouver', 'Portland', 'San Francisco', 'Seattle', 'Los Angeles',
#        'San Diego', 'Las Vegas', 'Phoenix', 'Albuquerque', 'Denver',
#        'San Antonio', 'Dallas', 'Houston', 'Kansas City', 'Minneapolis',
#        'Saint Louis', 'Chicago', 'Nashville', 'Indianapolis', 'Atlanta',
#        'Detroit', 'Jacksonville', 'Charlotte', 'Miami', 'Pittsburgh',
#        'Toronto', 'Philadelphia', 'New York', 'Montreal', 'Boston',
#        'Beersheba', 'Tel Aviv District', 'Eilat', 'Haifa', 'Nahariyya',
#        'Jerusalem'],
#       dtype='object')
#
# Weather Description DataFrame columns:
# Index(['Vancouver', 'Portland', 'San Francisco', 'Seattle', 'Los Angeles',
#        'San Diego', 'Las Vegas', 'Phoenix', 'Albuquerque', 'Denver',
#        'San Antonio', 'Dallas', 'Houston', 'Kansas City', 'Minneapolis',
#        'Saint Louis', 'Chicago', 'Nashville', 'Indianapolis', 'Atlanta',
#        'Detroit', 'Jacksonville', 'Charlotte', 'Miami', 'Pittsburgh',
#        'Toronto', 'Philadelphia', 'New York', 'Montreal', 'Boston',
#        'Beersheba', 'Tel Aviv District', 'Eilat', 'Haifa', 'Nahariyya',
#        'Jerusalem'],
#       dtype='object')

# %%
# ADDING DATETIME COLUMN

# Function to create a 'datetime' column assuming hourly intervals from a start date
def add_datetime_column(df, start_date='2020-01-01', freq='H'):
    # Generate a date range
    date_range = pd.date_range(start=start_date, periods=len(df), freq=freq)
    df['datetime'] = date_range

# Apply this function to each DataFrame
for df in dataframes:
    add_datetime_column(df)

# Now, set 'datetime' as the index for all dataframes
for df in dataframes:
    df.set_index('datetime', inplace=True)

# Ensure unique column names for merging
suffixes = ["_temp", "_humidity", "_pressure", "_windspeed", "_winddir", "_weatherdesc"]
for df, suffix in zip(dataframes, suffixes):
    df.columns = [f"{col}{suffix}" if col != 'datetime' else col for col in df.columns]

# Perform an outer merge to keep all timestamps from all datasets
from functools import reduce
combined_df = reduce(lambda left, right: pd.merge(left, right, on='datetime', how='outer'), dataframes)

# Display the head of the combined dataframe to check the merge
print(combined_df.head())

# Display summary of missing values after merging
print("\nCombined DataFrame Missing Values After Merging:")
print(combined_df.isnull().sum())
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/172568721.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   date_range = pd.date_range(start=start_date, periods=len(df), freq=freq)
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/172568721.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   date_range = pd.date_range(start=start_date, periods=len(df), freq=freq)
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/172568721.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   date_range = pd.date_range(start=start_date, periods=len(df), freq=freq)
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/172568721.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   date_range = pd.date_range(start=start_date, periods=len(df), freq=freq)
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/172568721.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   date_range = pd.date_range(start=start_date, periods=len(df), freq=freq)
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/172568721.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   date_range = pd.date_range(start=start_date, periods=len(df), freq=freq)
#                      Vancouver_Temperature_temp  Portland_Temperature_temp  \
# datetime
# 2020-01-01 00:00:00                  284.630000                 282.080000
# 2020-01-01 01:00:00                  284.630000                 282.080000
# 2020-01-01 02:00:00                  284.629041                 282.083252
# 2020-01-01 03:00:00                  284.626998                 282.091866
# 2020-01-01 04:00:00                  284.624955                 282.100481
#
#                      San Francisco_Temperature_temp  Seattle_Temperature_temp  \
# datetime
# 2020-01-01 00:00:00                      289.480000                281.800000
# 2020-01-01 01:00:00                      289.480000                281.800000
# 2020-01-01 02:00:00                      289.474993                281.797217
# 2020-01-01 03:00:00                      289.460618                281.789833
# 2020-01-01 04:00:00                      289.446243                281.782449
#
#                      Los Angeles_Temperature_temp  San Diego_Temperature_temp  \
# datetime
# 2020-01-01 00:00:00                    291.870000                  291.530000
# 2020-01-01 01:00:00                    291.870000                  291.530000
# 2020-01-01 02:00:00                    291.868186                  291.533501
# 2020-01-01 03:00:00                    291.862844                  291.543355
# 2020-01-01 04:00:00                    291.857503                  291.553209
#
#                      Las Vegas_Temperature_temp  Phoenix_Temperature_temp  \
# datetime
# 2020-01-01 00:00:00                  293.410000                296.600000
# 2020-01-01 01:00:00                  293.410000                296.600000
# 2020-01-01 02:00:00                  293.403141                296.608509
# 2020-01-01 03:00:00                  293.392177                296.631487
# 2020-01-01 04:00:00                  293.381213                296.654466
#
#                      Albuquerque_Temperature_temp  Denver_Temperature_temp  \
# datetime
# 2020-01-01 00:00:00                    285.120000               284.610000
# 2020-01-01 01:00:00                    285.120000               284.610000
# 2020-01-01 02:00:00                    285.154558               284.607306
# 2020-01-01 03:00:00                    285.233952               284.599918
# 2020-01-01 04:00:00                    285.313345               284.592530
#
#                      ...  Philadelphia_Weather Description_weatherdesc  \
# datetime             ...
# 2020-01-01 00:00:00  ...                                 broken clouds
# 2020-01-01 01:00:00  ...                                 broken clouds
# 2020-01-01 02:00:00  ...                                 broken clouds
# 2020-01-01 03:00:00  ...                                 broken clouds
# 2020-01-01 04:00:00  ...                                 broken clouds
#
#                      New York_Weather Description_weatherdesc  \
# datetime
# 2020-01-01 00:00:00                                few clouds
# 2020-01-01 01:00:00                                few clouds
# 2020-01-01 02:00:00                                few clouds
# 2020-01-01 03:00:00                                few clouds
# 2020-01-01 04:00:00                                few clouds
#
#                      Montreal_Weather Description_weatherdesc  \
# datetime
# 2020-01-01 00:00:00                           overcast clouds
# 2020-01-01 01:00:00                           overcast clouds
# 2020-01-01 02:00:00                              sky is clear
# 2020-01-01 03:00:00                              sky is clear
# 2020-01-01 04:00:00                              sky is clear
#
#                      Boston_Weather Description_weatherdesc  \
# datetime
# 2020-01-01 00:00:00                            sky is clear
# 2020-01-01 01:00:00                            sky is clear
# 2020-01-01 02:00:00                              few clouds
# 2020-01-01 03:00:00                              few clouds
# 2020-01-01 04:00:00                              few clouds
#
#                      Beersheba_Weather Description_weatherdesc  \
# datetime
# 2020-01-01 00:00:00                               sky is clear
# 2020-01-01 01:00:00                               sky is clear
# 2020-01-01 02:00:00                               sky is clear
# 2020-01-01 03:00:00                            overcast clouds
# 2020-01-01 04:00:00                            overcast clouds
#
#                      Tel Aviv District_Weather Description_weatherdesc  \
# datetime
# 2020-01-01 00:00:00                                       sky is clear
# 2020-01-01 01:00:00                                       sky is clear
# 2020-01-01 02:00:00                                       sky is clear
# 2020-01-01 03:00:00                                       sky is clear
# 2020-01-01 04:00:00                                       sky is clear
#
#                      Eilat_Weather Description_weatherdesc  \
# datetime
# 2020-01-01 00:00:00                                   haze
# 2020-01-01 01:00:00                                   haze
# 2020-01-01 02:00:00                          broken clouds
# 2020-01-01 03:00:00                          broken clouds
# 2020-01-01 04:00:00                          broken clouds
#
#                      Haifa_Weather Description_weatherdesc  \
# datetime
# 2020-01-01 00:00:00                           sky is clear
# 2020-01-01 01:00:00                           sky is clear
# 2020-01-01 02:00:00                        overcast clouds
# 2020-01-01 03:00:00                        overcast clouds
# 2020-01-01 04:00:00                        overcast clouds
#
#                      Nahariyya_Weather Description_weatherdesc  \
# datetime
# 2020-01-01 00:00:00                               sky is clear
# 2020-01-01 01:00:00                               sky is clear
# 2020-01-01 02:00:00                               sky is clear
# 2020-01-01 03:00:00                            overcast clouds
# 2020-01-01 04:00:00                            overcast clouds
#
#                      Jerusalem_Weather Description_weatherdesc
# datetime
# 2020-01-01 00:00:00                               sky is clear
# 2020-01-01 01:00:00                               sky is clear
# 2020-01-01 02:00:00                            overcast clouds
# 2020-01-01 03:00:00                            overcast clouds
# 2020-01-01 04:00:00                            overcast clouds
#
# [5 rows x 216 columns]
#
# Combined DataFrame Missing Values After Merging:
# Vancouver_Temperature_temp                           0
# Portland_Temperature_temp                            0
# San Francisco_Temperature_temp                       0
# Seattle_Temperature_temp                             0
# Los Angeles_Temperature_temp                         0
#                                                     ..
# Tel Aviv District_Weather Description_weatherdesc    0
# Eilat_Weather Description_weatherdesc                0
# Haifa_Weather Description_weatherdesc                0
# Nahariyya_Weather Description_weatherdesc            0
# Jerusalem_Weather Description_weatherdesc            0
# Length: 216, dtype: int64

# %%
# Display all column names to identify the correct target column
print("All columns in numeric_df:")
print(numeric_df.columns)
# Out:
# All columns in numeric_df:
# Index(['Vancouver_Temperature_temp', 'Portland_Temperature_temp',
#        'San Francisco_Temperature_temp', 'Seattle_Temperature_temp',
#        'Los Angeles_Temperature_temp', 'San Diego_Temperature_temp',
#        'Las Vegas_Temperature_temp', 'Phoenix_Temperature_temp',
#        'Albuquerque_Temperature_temp', 'Denver_Temperature_temp',
#        ...
#        'Philadelphia_Wind Direction_winddir',
#        'New York_Wind Direction_winddir', 'Montreal_Wind Direction_winddir',
#        'Boston_Wind Direction_winddir', 'Beersheba_Wind Direction_winddir',
#        'Tel Aviv District_Wind Direction_winddir',
#        'Eilat_Wind Direction_winddir', 'Haifa_Wind Direction_winddir',
#        'Nahariyya_Wind Direction_winddir', 'Jerusalem_Wind Direction_winddir'],
#       dtype='object', length=180)

# %%
# PREPROCESSING

# Drop non-numeric columns explicitly
columns_to_drop = [col for col in combined_df.columns if '_weatherdesc' in col]
numeric_df = combined_df.drop(columns=columns_to_drop, axis=1)

# Convert all columns to float, handling errors by coercing to NaN
numeric_df = numeric_df.apply(pd.to_numeric, errors='coerce')

# Identify and display columns with NaN values
nan_columns = numeric_df.columns[numeric_df.isna().any()].tolist()
print("Columns with NaN values before cleaning:", nan_columns)
print(numeric_df[nan_columns].isna().sum())

# Apply forward fill and backward fill to handle NaNs
numeric_df.fillna(method='ffill', inplace=True)
numeric_df.fillna(method='bfill', inplace=True)

# Recheck and handle remaining NaNs with mean imputation as a fallback
if numeric_df.isnull().any().any():
    numeric_df.fillna(numeric_df.mean(), inplace=True)

# Ensure there are no infinite values
numeric_df.replace([np.inf, -np.inf], np.nan, inplace=True)
numeric_df.fillna(method='ffill', inplace=True)  # Forward fill any infinities converted to NaN
numeric_df.fillna(method='bfill', inplace=True)  # Backward fill to handle remaining infinities

# Final check for NaN or infinite values in numeric_df
if numeric_df.isnull().any().any() or np.isinf(numeric_df).any().any():
    print("Data still contains NaN or Infinite values after all handling.")

# Initialize the scaler and scale the numeric data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(numeric_df)

# Use the correct target column name for New York's temperature data
target_column = 'New York_Temperature_temp'
if target_column in numeric_df.columns:
    target_index = numeric_df.columns.get_loc(target_column)
    target = scaled_features[:, target_index]
else:
    raise ValueError(f"{target_column} is not in DataFrame columns.")

# Final check for NaN or infinite values in scaled features and target
if np.isnan(scaled_features).any() or np.isnan(target).any():
    raise ValueError("Data still contains NaN values after all handling.")
if np.isinf(scaled_features).any() or np.isinf(target).any():
    raise ValueError("Data still contains Infinite values after all handling.")

# Confirm the shapes and data integrity before proceeding to the model
print("Final check - Scaled features shape:", scaled_features.shape)
print("Final check - Target shape:", target.shape)
# Out:
# Columns with NaN values before cleaning: []
# Series([], dtype: float64)
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/979553443.py:14: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   numeric_df.fillna(method='ffill', inplace=True)
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/979553443.py:15: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   numeric_df.fillna(method='bfill', inplace=True)
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/979553443.py:23: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   numeric_df.fillna(method='ffill', inplace=True)  # Forward fill any infinities converted to NaN
# C:\Users\HP\AppData\Local\Temp/ipykernel_57764/979553443.py:24: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   numeric_df.fillna(method='bfill', inplace=True)  # Backward fill to handle remaining infinities
# Final check - Scaled features shape: (45253, 180)
# Final check - Target shape: (45253,)

# %%
# CREATING TIME SERIES DATA FOR LSTM

from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# Define look_back and batch size for TimeseriesGenerator
look_back = 24  # Number of past hours to use for prediction
batch_size = 32

# Generate time series batches
train_size = int(len(scaled_features) * 0.8)
train_generator = TimeseriesGenerator(scaled_features, target,
                                      length=look_back, batch_size=batch_size,
                                      end_index=train_size - 1)  # Exclude last record for validation
test_generator = TimeseriesGenerator(scaled_features, target,
                                     length=look_back, batch_size=batch_size,
                                     start_index=train_size)

# %%
# BUILDING THE LSTM MODEL

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Build the LSTM model
model = Sequential([
    LSTM(50, input_shape=(look_back, scaled_features.shape[1]), return_sequences=True),
    Dropout(0.2),
    LSTM(50, return_sequences=False),
    Dropout(0.2),
    Dense(1)
])

# Compile the model with a smaller learning rate
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])

# Display the model summary to check the architecture
model.summary()
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_6 (LSTM)                   │ (None, 24, 50)         │        46,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 24, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 66,451 (259.57 KB)
#  Trainable params: 66,451 (259.57 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# TRAINING AND EVALUATING THE MODEL

import matplotlib.pyplot as plt

# Fit the model on the training data
history = model.fit(train_generator, epochs=20, validation_data=test_generator, verbose=1)

# Plot the training history
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# Plot the MAE history
plt.figure(figsize=(12, 6))
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.title('Model MAE Over Epochs')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# Evaluate the model's performance on the test set
test_metrics = model.evaluate(test_generator, verbose=1)
print(f"Test Loss: {test_metrics[0]}, Test MAE: {test_metrics[1]}")
# Out:
# Epoch 1/20
#    7/1131 ━━━━━━━━━━━━━━━━━━━━ 22s 20ms/step - loss: 0.4521 - mae: 0.6319
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - loss: 0.0455 - mae: 0.1538 - val_loss: 0.0047 - val_mae: 0.0533
# Epoch 2/20
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - loss: 0.0082 - mae: 0.0719 - val_loss: 0.0044 - val_mae: 0.0530
# Epoch 3/20
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - loss: 0.0065 - mae: 0.0643 - val_loss: 0.0060 - val_mae: 0.0614
# Epoch 4/20
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - loss: 0.0056 - mae: 0.0589 - val_loss: 0.0038 - val_mae: 0.0462
# Epoch 5/20
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - loss: 0.0051 - mae: 0.0565 - val_loss: 0.0036 - val_mae: 0.0476
# Epoch 6/20
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - loss: 0.0045 - mae: 0.0534 - val_loss: 0.0027 - val_mae: 0.0395
# Epoch 7/20
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - loss: 0.0042 - mae: 0.0514 - val_loss: 0.0027 - val_mae: 0.0385
# Epoch 8/20
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - loss: 0.0039 - mae: 0.0491 - val_loss: 0.0023 - val_mae: 0.0358
# Epoch 9/20
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - loss: 0.0037 - mae: 0.0480 - val_loss: 0.0023 - val_mae: 0.0353
# Epoch 10/20
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - loss: 0.0034 - mae: 0.0462 - val_loss: 0.0026 - val_mae: 0.0390
# Epoch 11/20
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - loss: 0.0032 - mae: 0.0441 - val_loss: 0.0020 - val_mae: 0.0340
# Epoch 12/20
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - loss: 0.0030 - mae: 0.0435 - val_loss: 0.0018 - val_mae: 0.0316
# Epoch 13/20
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 19s 17ms/step - loss: 0.0029 - mae: 0.0419 - val_loss: 0.0022 - val_mae: 0.0344
# Epoch 14/20
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 20s 17ms/step - loss: 0.0028 - mae: 0.0414 - val_loss: 0.0019 - val_mae: 0.0335
# Epoch 15/20
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - loss: 0.0028 - mae: 0.0412 - val_loss: 0.0016 - val_mae: 0.0298
# Epoch 16/20
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - loss: 0.0025 - mae: 0.0391 - val_loss: 0.0016 - val_mae: 0.0291
# Epoch 17/20
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 19s 17ms/step - loss: 0.0024 - mae: 0.0387 - val_loss: 0.0015 - val_mae: 0.0295
# Epoch 18/20
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - loss: 0.0023 - mae: 0.0372 - val_loss: 0.0015 - val_mae: 0.0272
# Epoch 19/20
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 19s 17ms/step - loss: 0.0022 - mae: 0.0368 - val_loss: 0.0015 - val_mae: 0.0278
# Epoch 20/20
# 1131/1131 ━━━━━━━━━━━━━━━━━━━━ 19s 17ms/step - loss: 0.0021 - mae: 0.0361 - val_loss: 0.0014 - val_mae: 0.0290
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0012 - mae: 0.0279
# Test Loss: 0.0014379776548594236, Test MAE: 0.029023393988609314

# %%
# Make predictions
predictions = model.predict(test_generator)

# Compare predictions to actual values
predicted_values = predictions.flatten()
actual_values = target[-len(predicted_values):]

# Plot the predictions against the actual values
plt.figure(figsize=(12, 6))
plt.plot(actual_values, label='Actual Values')
plt.plot(predicted_values, label='Predicted Values')
plt.title('Actual vs Predicted Values')
plt.ylabel('Temperature (scaled)')
plt.xlabel('Time Step')
plt.legend()
plt.show()
# Out:
# 283/283 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
